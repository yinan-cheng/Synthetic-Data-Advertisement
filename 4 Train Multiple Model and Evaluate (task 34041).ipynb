# %% [markdown]
# # Stage 0 Load Datasets

# %%
import pandas as pd
path = 'Data' # Path of the dataset folder
task_id = 34041 # Choose the task
df_train = pd.read_csv(f'{path}/task_{task_id}/df_{task_id}_train.csv')
df_syn_ctgan = pd.read_csv(f'{path}/task_{task_id}/df_{task_id}_syn_ctgan.csv')
df_syn_ctabgan = pd.read_csv(f'{path}/task_{task_id}/df_{task_id}_syn_ctabgan.csv')
df_syn_tvae = pd.read_csv(f'{path}/task_{task_id}/df_{task_id}_syn_tvae.csv')
df_syn_ds = pd.read_csv(f'{path}/task_{task_id}/df_{task_id}_syn_ds.csv')
df_syn_great = pd.read_csv(f'{path}/task_{task_id}/df_{task_id}_syn_great.csv')
df_syn_tabula = pd.read_csv(f'{path}/task_{task_id}/df_{task_id}_syn_tabula.csv')
df_holdout = pd.read_csv(f'{path}/task_{task_id}/df_{task_id}_holdout.csv')
df_val = pd.read_csv(f'{path}/task_{task_id}/df_{task_id}_val.csv')
print("data is loaded...")
# Out:
# data is loaded...

# %%
from Dataset_Utility import utility_functions as uf
uf.calculate_label_rate(df_train)
uf.calculate_label_rate(df_syn_ctgan)
uf.calculate_label_rate(df_syn_ctabgan)
uf.calculate_label_rate(df_syn_tvae)
uf.calculate_label_rate(df_syn_ds)
uf.calculate_label_rate(df_syn_great)
uf.calculate_label_rate(df_syn_tabula)
uf.calculate_label_rate(df_holdout)
uf.calculate_label_rate(df_val)
# Out:
# Total Sample size is 13920, Positive Sample size is 425, Negative Sample size is 13495, label rate is 0.03
# Total Sample size is 13920, Positive Sample size is 502, Negative Sample size is 13418, label rate is 0.04
# Total Sample size is 13920, Positive Sample size is 40, Negative Sample size is 13880, label rate is 0.00
# Total Sample size is 13920, Positive Sample size is 97, Negative Sample size is 13823, label rate is 0.01
# Total Sample size is 13920, Positive Sample size is 492, Negative Sample size is 13428, label rate is 0.04
# Total Sample size is 13920, Positive Sample size is 88, Negative Sample size is 13832, label rate is 0.01
# Total Sample size is 13920, Positive Sample size is 443, Negative Sample size is 13477, label rate is 0.03
# Total Sample size is 13920, Positive Sample size is 425, Negative Sample size is 13495, label rate is 0.03
# Total Sample size is 6963, Positive Sample size is 214, Negative Sample size is 6749, label rate is 0.03

# %% [markdown]
# # Stage 1 Train Classifier and Evaluate

# %%
#!pip install pygam
#!pip install xgboost
#!pip install git+https://github.com/lemeln/nam

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from pygam import LogisticGAM
from xgboost import XGBClassifier
from nam.wrapper import NAMClassifier

# Dictionary of models
models = {
    'LR': LogisticRegression(),
    'DT': DecisionTreeClassifier(random_state=0),
    'KNN': KNeighborsClassifier(),
    'NB': GaussianNB(),
    'SVM': SVC(random_state=0, probability=True),
    'RF': RandomForestClassifier(random_state=0),    
    #'GAM': LogisticGAM(), # Does not converge
    'XGB': XGBClassifier()#,
    #'NAM': NAMClassifier()
}

# Dictionary of samples
samples = {
    'Original': df_train, # training data
    'CTGAN': df_syn_ctgan,
    'CTABGAN': df_syn_ctabgan,
    'TVAE': df_syn_tvae,
    'DS': df_syn_ds,
    'GReaT': df_syn_great,
    'Tabula': df_syn_tabula
}

# %%
# Use the following loop, we can get sets of predictors and sets of response of each sample
# For example, X_CTGAN is the set of predictors for the df_syn_ctgan sample
for name, sample in samples.items():
    globals()[f'X_{name}'] = sample.drop('label', axis=1) # Predictors
    globals()[f'y_{name}'] = sample['label'] # Response

X_val = df_val.drop('label', axis=1) # Predictors of valide
y_val = df_val['label'] # Response of valid

# %%
from sklearn.preprocessing import StandardScaler 
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score
from sklearn.metrics import average_precision_score, precision_recall_curve, roc_curve, auc
from sklearn.metrics import f1_score,recall_score, precision_score

# Create a dataframe to save the result
sample_model = []
for sample in samples.keys():
    for model in models.keys():
        sample_model.append(f'{sample}_{model}')        
columns=['Accuracy', 'AUC', 'F1', 'Recall','Precision', 'AP','TPR', 'FPR', 'TNR', 'FNR']
result = pd.DataFrame(index = sample_model, columns=columns)

def model_evaluation(name, model, sample, X_train, y_train, X_val, y_val):
    # Standardize training set and valid set 
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    # Fit model
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    # Predict probabilities
    if ind == 1:
        y_proba = model.predict_proba(X_val) # When the model is GAM or NAM
    else:
        y_proba = model.predict_proba(X_val)[:,1] # Otherwise
    
    # Metric 1: accuracy
    accuracy = accuracy_score(y_val, y_pred)
    # Metric 2: ROC AUC
    auroc = roc_auc_score(y_val, y_proba)
    # Metric 3: F1 score
    f1 = f1_score(y_val, y_pred)
    # Metric 4: recall score
    recall = recall_score(y_val, y_pred) 
    # Metric 5: precision score
    precision = precision_score(y_val, y_pred)  
    # Metric 6: average_precision    
    ap = average_precision_score(y_val, y_proba)
    # Metric 7: confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_val, y_pred).ravel()
    tpr = tp / (tp + fn)  
    fpr = fp / (fp + tn)  
    tnr = tn / (tn + fp)  
    fnr = fn / (tp + fn)
    
    result.loc[f'{sample}_{name}'] = [
        round(accuracy, 3), round(auroc, 3), round(f1, 3), round(recall, 3), round(precision, 3), round(ap, 3),
        round(tpr, 3), round(fpr, 3), round(tnr, 3), round(fnr, 3)
    ]
    
    # For figures
    # ROC Curve
    fpr, tpr, _ = roc_curve(y_val, y_proba)
    roc_auc = auc(fpr, tpr)

    globals()[f'{sample}_{name}_fpr'] = fpr
    globals()[f'{sample}_{name}_tpr'] = tpr
    globals()[f'{sample}_{name}_auc'] = roc_auc
    
    # Precision-Recall Curve
    precision, recall, _ = precision_recall_curve(y_val, y_proba)
    ap = average_precision_score(y_val, y_proba)
    globals()[f'{sample}_{name}_precision'] = precision
    globals()[f'{sample}_{name}_recall'] = recall
    globals()[f'{sample}_{name}_ap'] = ap
    
    #print(sample + " "+ name +" done")

# %% [markdown]
# ***There are warnings showing results have value 0 for some precisions.***

# %%
for sample in samples.keys():
    X_train = globals()[f'X_{sample}']
    y_train = globals()[f'y_{sample}']
    for name, model in models.items():
        if name == "GAM" or name == "NAM":
            ind = 1
        else:
            ind = 0
        model_evaluation(name, model, sample, X_train, y_train, X_val, y_val)

result.to_csv(f"{path}/task_{task_id}/result.csv", index = True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # Stage 2 Evaluation Result

# %%
# Ordered by sample names
result
# Out:
#              Accuracy    AUC     F1 Recall Precision     AP    TPR    FPR  \
# Original_LR     0.969   0.77    0.0    0.0       0.0  0.113    0.0    0.0
# Original_DT      0.95  0.637  0.232  0.243     0.221   0.09  0.243  0.027
# Original_KNN    0.968   0.67  0.083  0.047      0.37  0.086  0.047  0.003
# Original_NB     0.935  0.764  0.166   0.21     0.137  0.107   0.21  0.042
# Original_SVM    0.969  0.612    0.0    0.0       0.0   0.11    0.0    0.0
# Original_RF     0.967  0.808  0.235  0.164     0.417  0.229  0.164  0.007
# Original_XGB    0.969  0.763  0.222  0.145     0.477  0.218  0.145  0.005
# CTGAN_LR        0.968  0.723    0.0    0.0       0.0  0.078    0.0  0.001
# CTGAN_DT        0.941   0.54  0.105  0.112     0.099  0.038  0.112  0.032
# CTGAN_KNN        0.96   0.55   0.09  0.065     0.146  0.044  0.065  0.012
# CTGAN_NB        0.428  0.721  0.085  0.869     0.045  0.082  0.869  0.586
# CTGAN_SVM       0.968  0.556  0.058  0.033     0.269  0.056  0.033  0.003
# CTGAN_RF        0.963  0.655  0.085  0.056     0.176  0.079  0.056  0.008
# CTGAN_XGB       0.958  0.611  0.093   0.07     0.139  0.062   0.07  0.014
# CTABGAN_LR      0.969  0.646    0.0    0.0       0.0  0.054    0.0    0.0
# CTABGAN_DT      0.957    0.5   0.02  0.014     0.032  0.031  0.014  0.013
# CTABGAN_KNN     0.969  0.496    0.0    0.0       0.0  0.031    0.0    0.0
# CTABGAN_NB      0.079  0.638  0.062  0.995     0.032  0.071  0.995   0.95
# CTABGAN_SVM     0.969  0.455    0.0    0.0       0.0  0.029    0.0    0.0
# CTABGAN_RF      0.969  0.598    0.0    0.0       0.0   0.05    0.0    0.0
# CTABGAN_XGB     0.969  0.561  0.009  0.005       1.0  0.045  0.005    0.0
# TVAE_LR         0.969  0.719    0.0    0.0       0.0  0.081    0.0    0.0
# TVAE_DT         0.955  0.536  0.109  0.089      0.14   0.04  0.089  0.017
# TVAE_KNN        0.969  0.508    0.0    0.0       0.0  0.031    0.0    0.0
# TVAE_NB         0.697  0.545  0.039  0.201     0.022  0.031  0.201  0.287
# TVAE_SVM        0.969  0.491    0.0    0.0       0.0  0.033    0.0    0.0
# TVAE_RF         0.969    0.7    0.0    0.0       0.0  0.062    0.0    0.0
# TVAE_XGB        0.968  0.677    0.0    0.0       0.0  0.063    0.0  0.001
# DS_LR           0.969  0.775    0.0    0.0       0.0  0.129    0.0    0.0
# DS_DT           0.935  0.532  0.088  0.103     0.077  0.036  0.103  0.039
# DS_KNN          0.968  0.591  0.018  0.009     0.154  0.045  0.009  0.002
# DS_NB            0.96  0.769  0.096   0.07     0.155  0.113   0.07  0.012
# DS_SVM          0.969  0.561    0.0    0.0       0.0  0.057    0.0    0.0
# DS_RF           0.969  0.727    0.0    0.0       0.0  0.099    0.0    0.0
# DS_XGB          0.969  0.717    0.0    0.0       0.0  0.086    0.0    0.0
# GReaT_LR        0.969  0.607    0.0    0.0       0.0  0.044    0.0    0.0
# GReaT_DT         0.96  0.498  0.007  0.005     0.015  0.031  0.005   0.01
# GReaT_KNN       0.969  0.499    0.0    0.0       0.0  0.031    0.0    0.0
# GReaT_NB        0.954  0.516  0.006  0.005     0.009  0.033  0.005  0.016
# GReaT_SVM       0.969  0.535    0.0    0.0       0.0  0.036    0.0    0.0
# GReaT_RF        0.969  0.548    0.0    0.0       0.0  0.036    0.0    0.0
# GReaT_XGB       0.969  0.501    0.0    0.0       0.0  0.034    0.0  0.001
# Tabula_LR       0.969  0.754    0.0    0.0       0.0  0.098    0.0    0.0
# Tabula_DT       0.936  0.546  0.115  0.136       0.1  0.041  0.136  0.039
# Tabula_KNN      0.968  0.567  0.009  0.005     0.111  0.039  0.005  0.001
# Tabula_NB        0.95  0.731  0.044  0.037     0.053  0.075  0.037  0.021
# Tabula_SVM      0.969  0.562    0.0    0.0       0.0  0.052    0.0    0.0
# Tabula_RF       0.966  0.734  0.008  0.005     0.042   0.08  0.005  0.003
# Tabula_XGB      0.967  0.671  0.041  0.023     0.185  0.077  0.023  0.003
#
#                 TNR    FNR
# Original_LR     1.0    1.0
# Original_DT   0.973  0.757
# Original_KNN  0.997  0.953
# Original_NB   0.958   0.79
# Original_SVM    1.0    1.0
# Original_RF   0.993  0.836
# Original_XGB  0.995  0.855
# CTGAN_LR      0.999    1.0
# CTGAN_DT      0.968  0.888
# CTGAN_KNN     0.988  0.935
# CTGAN_NB      0.414  0.131
# CTGAN_SVM     0.997  0.967
# CTGAN_RF      0.992  0.944
# CTGAN_XGB     0.986   0.93
# CTABGAN_LR      1.0    1.0
# CTABGAN_DT    0.987  0.986
# CTABGAN_KNN     1.0    1.0
# CTABGAN_NB     0.05  0.005
# CTABGAN_SVM     1.0    1.0
# CTABGAN_RF      1.0    1.0
# CTABGAN_XGB     1.0  0.995
# TVAE_LR         1.0    1.0
# TVAE_DT       0.983  0.911
# TVAE_KNN        1.0    1.0
# TVAE_NB       0.713  0.799
# TVAE_SVM        1.0    1.0
# TVAE_RF         1.0    1.0
# TVAE_XGB      0.999    1.0
# DS_LR           1.0    1.0
# DS_DT         0.961  0.897
# DS_KNN        0.998  0.991
# DS_NB         0.988   0.93
# DS_SVM          1.0    1.0
# DS_RF           1.0    1.0
# DS_XGB          1.0    1.0
# GReaT_LR        1.0    1.0
# GReaT_DT       0.99  0.995
# GReaT_KNN       1.0    1.0
# GReaT_NB      0.984  0.995
# GReaT_SVM       1.0    1.0
# GReaT_RF        1.0    1.0
# GReaT_XGB     0.999    1.0
# Tabula_LR       1.0    1.0
# Tabula_DT     0.961  0.864
# Tabula_KNN    0.999  0.995
# Tabula_NB     0.979  0.963
# Tabula_SVM      1.0    1.0
# Tabula_RF     0.997  0.995
# Tabula_XGB    0.997  0.977

# %%
# Result 2 only has a different order of index from above result
# Ordered by model names

model_sample = []
for model in models.keys():
    for sample in samples.keys():
        model_sample.append(f'{model}_{sample}')
        
columns=['Accuracy', 'AUC', 'F1', 'Recall','Precision', 'AP','TPR', 'FPR', 'TNR', 'FNR']
result2 = pd.DataFrame(index = model_sample, columns=columns)

for name, model in models.items():
    for sample in samples.keys():
        result2.loc[f'{name}_{sample}'] = result.loc[f'{sample}_{name}']
        
result2
# Out:
#              Accuracy    AUC     F1 Recall Precision     AP    TPR    FPR  \
# LR_Original     0.969   0.77    0.0    0.0       0.0  0.113    0.0    0.0
# LR_CTGAN        0.968  0.723    0.0    0.0       0.0  0.078    0.0  0.001
# LR_CTABGAN      0.969  0.646    0.0    0.0       0.0  0.054    0.0    0.0
# LR_TVAE         0.969  0.719    0.0    0.0       0.0  0.081    0.0    0.0
# LR_DS           0.969  0.775    0.0    0.0       0.0  0.129    0.0    0.0
# LR_GReaT        0.969  0.607    0.0    0.0       0.0  0.044    0.0    0.0
# LR_Tabula       0.969  0.754    0.0    0.0       0.0  0.098    0.0    0.0
# DT_Original      0.95  0.637  0.232  0.243     0.221   0.09  0.243  0.027
# DT_CTGAN        0.941   0.54  0.105  0.112     0.099  0.038  0.112  0.032
# DT_CTABGAN      0.957    0.5   0.02  0.014     0.032  0.031  0.014  0.013
# DT_TVAE         0.955  0.536  0.109  0.089      0.14   0.04  0.089  0.017
# DT_DS           0.935  0.532  0.088  0.103     0.077  0.036  0.103  0.039
# DT_GReaT         0.96  0.498  0.007  0.005     0.015  0.031  0.005   0.01
# DT_Tabula       0.936  0.546  0.115  0.136       0.1  0.041  0.136  0.039
# KNN_Original    0.968   0.67  0.083  0.047      0.37  0.086  0.047  0.003
# KNN_CTGAN        0.96   0.55   0.09  0.065     0.146  0.044  0.065  0.012
# KNN_CTABGAN     0.969  0.496    0.0    0.0       0.0  0.031    0.0    0.0
# KNN_TVAE        0.969  0.508    0.0    0.0       0.0  0.031    0.0    0.0
# KNN_DS          0.968  0.591  0.018  0.009     0.154  0.045  0.009  0.002
# KNN_GReaT       0.969  0.499    0.0    0.0       0.0  0.031    0.0    0.0
# KNN_Tabula      0.968  0.567  0.009  0.005     0.111  0.039  0.005  0.001
# NB_Original     0.935  0.764  0.166   0.21     0.137  0.107   0.21  0.042
# NB_CTGAN        0.428  0.721  0.085  0.869     0.045  0.082  0.869  0.586
# NB_CTABGAN      0.079  0.638  0.062  0.995     0.032  0.071  0.995   0.95
# NB_TVAE         0.697  0.545  0.039  0.201     0.022  0.031  0.201  0.287
# NB_DS            0.96  0.769  0.096   0.07     0.155  0.113   0.07  0.012
# NB_GReaT        0.954  0.516  0.006  0.005     0.009  0.033  0.005  0.016
# NB_Tabula        0.95  0.731  0.044  0.037     0.053  0.075  0.037  0.021
# SVM_Original    0.969  0.612    0.0    0.0       0.0   0.11    0.0    0.0
# SVM_CTGAN       0.968  0.556  0.058  0.033     0.269  0.056  0.033  0.003
# SVM_CTABGAN     0.969  0.455    0.0    0.0       0.0  0.029    0.0    0.0
# SVM_TVAE        0.969  0.491    0.0    0.0       0.0  0.033    0.0    0.0
# SVM_DS          0.969  0.561    0.0    0.0       0.0  0.057    0.0    0.0
# SVM_GReaT       0.969  0.535    0.0    0.0       0.0  0.036    0.0    0.0
# SVM_Tabula      0.969  0.562    0.0    0.0       0.0  0.052    0.0    0.0
# RF_Original     0.967  0.808  0.235  0.164     0.417  0.229  0.164  0.007
# RF_CTGAN        0.963  0.655  0.085  0.056     0.176  0.079  0.056  0.008
# RF_CTABGAN      0.969  0.598    0.0    0.0       0.0   0.05    0.0    0.0
# RF_TVAE         0.969    0.7    0.0    0.0       0.0  0.062    0.0    0.0
# RF_DS           0.969  0.727    0.0    0.0       0.0  0.099    0.0    0.0
# RF_GReaT        0.969  0.548    0.0    0.0       0.0  0.036    0.0    0.0
# RF_Tabula       0.966  0.734  0.008  0.005     0.042   0.08  0.005  0.003
# XGB_Original    0.969  0.763  0.222  0.145     0.477  0.218  0.145  0.005
# XGB_CTGAN       0.958  0.611  0.093   0.07     0.139  0.062   0.07  0.014
# XGB_CTABGAN     0.969  0.561  0.009  0.005       1.0  0.045  0.005    0.0
# XGB_TVAE        0.968  0.677    0.0    0.0       0.0  0.063    0.0  0.001
# XGB_DS          0.969  0.717    0.0    0.0       0.0  0.086    0.0    0.0
# XGB_GReaT       0.969  0.501    0.0    0.0       0.0  0.034    0.0  0.001
# XGB_Tabula      0.967  0.671  0.041  0.023     0.185  0.077  0.023  0.003
#
#                 TNR    FNR
# LR_Original     1.0    1.0
# LR_CTGAN      0.999    1.0
# LR_CTABGAN      1.0    1.0
# LR_TVAE         1.0    1.0
# LR_DS           1.0    1.0
# LR_GReaT        1.0    1.0
# LR_Tabula       1.0    1.0
# DT_Original   0.973  0.757
# DT_CTGAN      0.968  0.888
# DT_CTABGAN    0.987  0.986
# DT_TVAE       0.983  0.911
# DT_DS         0.961  0.897
# DT_GReaT       0.99  0.995
# DT_Tabula     0.961  0.864
# KNN_Original  0.997  0.953
# KNN_CTGAN     0.988  0.935
# KNN_CTABGAN     1.0    1.0
# KNN_TVAE        1.0    1.0
# KNN_DS        0.998  0.991
# KNN_GReaT       1.0    1.0
# KNN_Tabula    0.999  0.995
# NB_Original   0.958   0.79
# NB_CTGAN      0.414  0.131
# NB_CTABGAN     0.05  0.005
# NB_TVAE       0.713  0.799
# NB_DS         0.988   0.93
# NB_GReaT      0.984  0.995
# NB_Tabula     0.979  0.963
# SVM_Original    1.0    1.0
# SVM_CTGAN     0.997  0.967
# SVM_CTABGAN     1.0    1.0
# SVM_TVAE        1.0    1.0
# SVM_DS          1.0    1.0
# SVM_GReaT       1.0    1.0
# SVM_Tabula      1.0    1.0
# RF_Original   0.993  0.836
# RF_CTGAN      0.992  0.944
# RF_CTABGAN      1.0    1.0
# RF_TVAE         1.0    1.0
# RF_DS           1.0    1.0
# RF_GReaT        1.0    1.0
# RF_Tabula     0.997  0.995
# XGB_Original  0.995  0.855
# XGB_CTGAN     0.986   0.93
# XGB_CTABGAN     1.0  0.995
# XGB_TVAE      0.999    1.0
# XGB_DS          1.0    1.0
# XGB_GReaT     0.999    1.0
# XGB_Tabula    0.997  0.977

# %%
import matplotlib.pyplot as plt

# Plot of Accuracy
for sample in samples.keys():
    accuracy = []
    for model in models.keys():
        accuracy.append(result.loc[f'{sample}_{model}']["Accuracy"])
    plt.plot(models.keys(), accuracy , 'o-', label=f'{sample}')
plt.xlabel('Interpretability')
plt.ylabel('Accuracy')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot of AUC

for sample in samples.keys():
    auc = []
    for model in models.keys():
        auc.append(result.loc[f'{sample}_{model}']["AUC"])
    plt.plot(models.keys(), auc , 'o-', label=f'{sample}')
plt.xlabel('Interpretability')
plt.ylabel('AUC')
plt.legend(loc="lower right")
plt.show()

# %%
# Plot of ROC Curves for different samples
# Labels are models

for sample in samples.keys():
    for name, model in models.items():
        roc_auc = globals()[f'{sample}_{name}_auc']
        plt.plot(globals()[f'{sample}_{name}_fpr'], globals()[f'{sample}_{name}_tpr'], lw=2, label=f'{name} ROC (area = {roc_auc:.2f})')
        
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'Receiver Operating Characteristic (ROC) Curves for {sample}')
    plt.legend(loc="lower right")
    plt.show()

# %%
# Plot of ROC Curves for different models
# Labels are samples

for name, model in models.items():
    for sample in samples.keys():
        roc_auc = globals()[f'{sample}_{name}_auc']
        plt.plot(globals()[f'{sample}_{name}_fpr'], globals()[f'{sample}_{name}_tpr'], lw=2, label=f'{sample} ROC (area = {roc_auc:.2f})')
        
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'Receiver Operating Characteristic (ROC) Curves for {name}')
    plt.legend(loc="lower right")
    plt.show()

# %%
# Plot of Precision-Recall Curves for different samples
# Labels are models

for sample in samples.keys():
    for name, model in models.items():
        ap = globals()[f'{sample}_{name}_ap']
        plt.plot(globals()[f'{sample}_{name}_recall'], globals()[f'{sample}_{name}_precision'], lw=2, label=f'{name} PR (AP = {ap:.2f})')
        
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(f'Precision-Recall Curves for {sample}')
    plt.legend(loc="upper right")
    plt.show()

# %%
# Plot of Precision-Recall Curves for different models
# Labels are samples

for name, model in models.items():
    for sample in samples.keys():
        ap = globals()[f'{sample}_{name}_ap']
        plt.plot(globals()[f'{sample}_{name}_recall'], globals()[f'{sample}_{name}_precision'], lw=2, label=f'{sample} PR (AP = {ap:.2f})')
        
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(f'Precision-Recall Curves for {name}')
    plt.legend(loc="upper right")
    plt.show()
